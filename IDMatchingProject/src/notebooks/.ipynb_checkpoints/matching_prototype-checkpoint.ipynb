# %% [markdown]
# ### Matching Registrants between 2 years of data -- This is a prototype!

# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Sep 30, 2018

This is my python version of the guest record matching project.

The application will match the guests record in different years and show versions.

@author: Grejell
"""
import numpy as np
import pandas as pd
import os

# %% [markdown]
# Set the directory

# %%
os.chdir('C:/Users/Grejell/AnacondaProjects/IDMatchingProject/')

# %% [markdown]
# Load the 2 data sets to match

# %%
yearOneData = pd.read_csv("./dta/yearOne.csv", engine='python')
yearTwoData = pd.read_csv("./dta/yearTwo.csv", engine='python')

# %% [markdown]
# Retain the columns to be used for matching

# %%
yearOneData = yearOneData[["10DigitCardNumber", "FirstName", "Surname", "Position", "Email", "CompanyName"]]
yearTwoData = yearTwoData[["10DigitCardNumber", "FirstName", "Surname", "Position", "Email", "CompanyName"]]

# %% [markdown]
# This function removes non alpha numeric characters and set all the strings to lower case

# %%
def function_1(df):
    columns = ["FirstName", "Surname", "Position", "Email", "CompanyName"]
    for column in columns:
        df[column] = df[column].str.replace(r'[^A-z0-9]', '').str.lower()
    return df

yearOneData = function_1(yearOneData)
yearTwoData = function_1(yearTwoData)

# %% [markdown]
# This function replaces blank cells to Nan and create a column that counts the number of Nan from First Name to Company Name

# %%
def function_2(df):
    df.replace(r'^\s*$', np.nan, regex=True, inplace = True)
    df['countNan'] = df.loc[:,'FirstName':'CompanyName'].count(axis=1)
    return df

yearOneData = function_2(yearOneData)
yearTwoData = function_2(yearTwoData)

# %% [markdown]
# This function concatenates the columns for the reference of matching between the data frames

# %%
def function_3(df):
    newCols = ['combo1', 'combo2', 'combo3', 'combo4', 'combo5', 'combo6', 'combo7', 'combo8', 'combo9', 'combo10', 'combo11']
    for cols in newCols:
        df.cols = pd.Series()
    df['Email'] = df['Email'].str.replace(r'_', '')
    df.loc[df.countNan > 2,'combo1' ] = df.FirstName+df.Surname+df.Position+df.Email+df.CompanyName
    df.loc[pd.notnull(df.FirstName) & pd.notnull(df.Surname) & pd.notnull(df.Position) & pd.notnull(df.CompanyName), 'combo2' ] = df.FirstName+df.Surname+df.Position+df.CompanyName
    df.loc[pd.notnull(df.FirstName) & pd.notnull(df.Surname) & pd.notnull(df.Email) & pd.notnull(df.CompanyName),'combo3' ] = df.FirstName+df.Surname+df.Email+df.CompanyName
    df.loc[pd.notnull(df.FirstName) & pd.notnull(df.Surname) & pd.notnull(df.CompanyName), 'combo4' ] = df.FirstName+df.Surname+df.CompanyName
    df.loc[pd.notnull(df.FirstName) & pd.notnull(df.Surname) & pd.notnull(df.Position), 'combo5' ] = df.FirstName+df.Surname+df.Position
    df.loc[pd.notnull(df.Position) & pd.notnull(df.Email) & pd.notnull(df.CompanyName), 'combo6' ] = df.Position+df.Email+df.CompanyName
    df.loc[pd.notnull(df.FirstName) & pd.notnull(df.Surname) & pd.notnull(df.Email), 'combo7' ] = df.FirstName+df.Surname+df.Email
    df['combo8'] = df.Email
    df.loc[pd.notnull(df.Position) & pd.notnull(df.Email), 'combo9' ] = df.Position+df.Email
    df.loc[pd.notnull(df.FirstName) & pd.notnull(df.Surname), 'combo10'] = df.FirstName+df.Surname
    df.loc[pd.notnull(df.Position) & pd.notnull(df.CompanyName), 'combo11'] = df.Position+df.CompanyName
    return df

yearOneData = function_3(yearOneData)
yearTwoData = function_3(yearTwoData)

# %% [markdown]
# This is a function that merges/matches data1 to data2 using the concatenation combos

# %%
def function_4(df1, df2):
    data = df2[['10DigitCardNumber', 'FirstName', 'Surname', 'Position', 'Email', 'CompanyName']]    
    combos = ['combo1', 'combo2', 'combo3', 'combo4', 'combo5', 'combo6', 'combo7', 'combo8', 'combo9', 'combo10', 'combo11']
    for combo in combos:
        mergeData = pd.merge(df2[['10DigitCardNumber', combo]], df1.loc[pd.notnull(df1[combo]),['10DigitCardNumber', combo]], how = 'left', on = combo)
        mergeData = mergeData[mergeData['10DigitCardNumber_y'].notnull()]
        #mergeData = mergeData.drop([combo], axis = 1)
        mergeData = mergeData.rename(columns = {'10DigitCardNumber_x': '10DigitCardNumber', '10DigitCardNumber_y': combo+'10DigitCardNumber'})
        data = pd.merge(data, mergeData, how = 'left', on = '10DigitCardNumber').drop_duplicates()
    return data

data = function_4(yearOneData, yearTwoData)

# %%
data.head()
# Out:
#   10DigitCardNumber FirstName   Surname                 Position  \
# 0        3797000215      caio    gaetan           tradeoperation
# 1        3797000964     syeda      khan  freelanceadminexecutive
# 2        3797001570   basheer  qafisheh           generalmanager
# 3        3797001588    hamzah  alhamzah                    chief
# 4        3797003188    larisa    dsouza                  student
#
#                     Email CompanyName  combo110DigitCardNumber  \
# 0  caiogaetanalghuraircom         NaN                      NaN
# 1      syedakhan1yahoocom         NaN                      NaN
# 2  blueskycom1111gmailcom         NaN                      NaN
# 3    gooldangalhotmailcom         NaN                      NaN
# 4  larisadsouzaoutlookcom         NaN                      NaN
#
#    combo210DigitCardNumber  combo310DigitCardNumber  combo410DigitCardNumber  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    combo510DigitCardNumber  combo610DigitCardNumber  combo710DigitCardNumber  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN             7.997004e+09
# 2                      NaN                      NaN             7.197007e+09
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    combo810DigitCardNumber  combo910DigitCardNumber  combo1010DigitCardNumber  \
# 0                      NaN                      NaN                       NaN
# 1             7.997004e+09                      NaN              7.997004e+09
# 2             7.197007e+09                      NaN              7.197007e+09
# 3                      NaN                      NaN                       NaN
# 4                      NaN                      NaN                       NaN
#
#    combo1110DigitCardNumber
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
data['match'] = pd.Series()
data.loc[pd.notnull(data.combo1), 'match'] = data['combo110DigitCardNumber']
data.loc[pd.isnull(data.combo1) & pd.notnull(data.combo2), 'match'] = data['combo210DigitCardNumber']
data.loc[pd.isnull(data.combo1) & pd.isnull(data.combo2) & pd.notnull(data.combo3), 'match'] = data['combo310DigitCardNumber']
data.loc[pd.isnull(data.combo1) & pd.isnull(data.combo2) & pd.isnull(data.combo3) & pd.notnull(data.combo4), 'match'] = data['combo410DigitCardNumber']
data.loc[pd.isnull(data.combo1) & pd.isnull(data.combo2) & pd.isnull(data.combo3) & pd.isnull(data.combo4) & pd.notnull(data.combo5), 'match'] = data['combo510DigitCardNumber']
data.loc[pd.isnull(data.combo1) & pd.isnull(data.combo2) & pd.isnull(data.combo3) & pd.isnull(data.combo4) & pd.isnull(data.combo5) & pd.notnull(data.combo6), 'match'] = data['combo610DigitCardNumber']
data.loc[pd.isnull(data.combo1) & pd.isnull(data.combo2) & pd.isnull(data.combo3) & pd.isnull(data.combo4) & pd.isnull(data.combo5) & pd.isnull(data.combo6) & pd.notnull(data.combo7), 'match'] = data['combo710DigitCardNumber']
data.loc[pd.isnull(data.combo1) & pd.isnull(data.combo2) & pd.isnull(data.combo3) & pd.isnull(data.combo4) & pd.isnull(data.combo5) & pd.isnull(data.combo6) & pd.isnull(data.combo7) & pd.notnull(data.combo8), 'match'] = data['combo810DigitCardNumber']
data.loc[pd.isnull(data.combo1) & pd.isnull(data.combo2) & pd.isnull(data.combo3) & pd.isnull(data.combo4) & pd.isnull(data.combo5) & pd.isnull(data.combo6) & pd.isnull(data.combo7) & pd.isnull(data.combo8) & pd.notnull(data.combo9), 'match'] = data['combo910DigitCardNumber']
data.loc[pd.isnull(data.combo1) & pd.isnull(data.combo2) & pd.isnull(data.combo3) & pd.isnull(data.combo4) & pd.isnull(data.combo5) & pd.isnull(data.combo6) & pd.isnull(data.combo7) & pd.isnull(data.combo8) & pd.isnull(data.combo9) & pd.notnull(data.combo10), 'match'] = data['combo1010DigitCardNumber']
data.loc[pd.isnull(data.combo1) & pd.isnull(data.combo2) & pd.isnull(data.combo3) & pd.isnull(data.combo4) & pd.isnull(data.combo5) & pd.isnull(data.combo6) & pd.isnull(data.combo7) & pd.isnull(data.combo8) & pd.isnull(data.combo9) & pd.isnull(data.combo10) & pd.notnull(data.combo11), 'match'] = data['combo1110DigitCardNumber']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-5749a4e3e88f> in <module>()
#       1 data['match'] = pd.Series()
# ----> 2 data.loc[pd.notnull(data.combo1), 'match'] = data['combo110DigitCardNumber']
#       3 data.loc[pd.isnull(data.combo1) & pd.notnull(data.combo2), 'match'] = data['combo210DigitCardNumber']
#       4 data.loc[pd.isnull(data.combo1) & pd.isnull(data.combo2) & pd.notnull(data.combo3), 'match'] = data['combo310DigitCardNumber']
#       5 data.loc[pd.isnull(data.combo1) & pd.isnull(data.combo2) & pd.isnull(data.combo3) & pd.notnull(data.combo4), 'match'] = data['combo410DigitCardNumber']
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'combo1'

# %%
data
# Out:
#       10DigitCardNumber       FirstName         Surname  \
# 0            3797000215            caio          gaetan
# 1            3797000964           syeda            khan
# 2            3797001570         basheer        qafisheh
# 3            3797001588          hamzah        alhamzah
# 4            3797003188          larisa          dsouza
# 5            3797003347           sneha          sharma
# 6            3797003355           ronak            gera
# 7            3797003484          sathar           zedie
# 8            3797003673          shakir        mohammad
# 9            3797004285              sd           kiran
# 10           3797004328           evana               a
# 11           3797004436        muhammed             ali
# 12           3797004524           rashi         kothari
# 13           3797004816           samir            bedi
# 14           3797006163           abbas         lalljee
# 15           3797006165        abdullah        mujadidy
# 16           3797006967           julia             rex
# 17           3797006982         ibrahim           awadh
# 18           3797007011            sara           raziq
# 19           3797007264          fakhar          yousaf
# 20           3797007286           simin       kodakadan
# 21           3797007299          raheel           tahir
# 22           3797007313       elisabeta        gorgovan
# 23           3797007697      frederique           simon
# 24           3797008099         farheen           panja
# 25           3797008467            joan         bakerly
# 26           3797008525          afroze       anisnawaz
# 27           3797008668           deepa        jaisingh
# 28           3797008818  mashaelmustafa          faqihi
# 29           3797008825         zoopeer      ershadpoor
# ...                 ...             ...             ...
# 41265        3797013544           mehdi  mrpangtanamiri
# 41266        3797007256       christoph            kind
# 41267        3797021341        mohammed          alsaeh
# 41268        3797017529            saad            said
# 41269        3797005914           nanni        espiritu
# 41270        3797020520            elie          badawi
# 41271        3709037540           osama          ghosen
# 41272        3797028346          rajish           kumar
# 41273        3798001678          ghenwa         tarabay
# 41274        3797025774     paulineanne        espiritu
# 41275        3797026166          suresh           kumar
# 41276        3797026166          suresh           kumar
# 41277        3797022872          mukesh        chhabria
# 41278        3797030346         claudie       chatelard
# 41279        3797003655       florencia       beschtedt
# 41280        3797012263          carlos      delosmozos
# 41281        3797025554        veronica         frances
# 41282        3797020492           ninad            save
# 41283        3797020484           arpit           patwa
# 41284        3797020476           rahul           popat
# 41285        3797020465          dhaval         panchal
# 41286        3797001714           okyar        gokpinar
# 41287        3797003068          hannah            joao
# 41288        3797005869          thomas            easo
# 41289        3797003899            jino       anirudhan
# 41290        3797021306        moahmmad         rafiael
# 41291        3797028817            jove         sucgang
# 41292        3797003910        michelle             san
# 41293        3797012625        muhammed           aslam
# 41294        3797005149    zeeshanabdul          hafeez
#
#                              Position                         Email  \
# 0                      tradeoperation        caiogaetanalghuraircom
# 1             freelanceadminexecutive            syedakhan1yahoocom
# 2                      generalmanager        blueskycom1111gmailcom
# 3                               chief          gooldangalhotmailcom
# 4                             student        larisadsouzaoutlookcom
# 5                             manager      shivangimathur30gmailcom
# 6                      generalmanager            geraronak9yahoocom
# 7                          instructor            amforzedhotmailcom
# 8                 salesrepresentative          rajujhansihotmailcom
# 9                                 NaN      gurukirankiranhotmailcom
# 10                     generalmanager            podravkapodravkaae
# 11                      exportmanager     hamitcilcilsancikolatacom
# 12                freelanceconsultant        rashikotharihotmailcom
# 13                   managingdirector         samirbrandskonnectcom
# 14                    managingpartner     alalljeeseiseigourmentcom
# 15                   managingdirector            mujadidymujezatcom
# 16                            student              juliarexgmailcom
# 17                                ceo                im8411gmailcom
# 18                       chefinpastry       chefsarafazal22yahoocom
# 19                              owner             dot2printyahoocom
# 20                  operationsmanager               siminvkgmailcom
# 21                              owner           raheeltahirgmailcom
# 22              assistanthotelmanager          elisadumitruyahoocom
# 23        pastrybakerycategorymanager   frederiquechefmiddleeastcom
# 24                                NaN        rizuuanpanjahotmailcom
# 25                            student         joanbakerlyhotmailcom
# 26           seniormarketingexecutive       afrozeanisnawazgmailcom
# 27                   bloggerandwriter             deepa2984gmailcom
# 28          freelanceinteriordesigner              mashaelfgmailcom
# 29                     projectmanager                zooperyahoocom
# ...                               ...                           ...
# 41265                         manager               infozubinteacom
# 41266                managingdirector           gbraunzhugermanycom
# 41267                     businessman             mohds1434gmailcom
# 41268                         manager             saadorghotmailcom
# 41269                       assistant              pazuhourgroupcom
# 41270                  generalmanager          ebadawizuhourgroupae
# 41271               purchasingmanager         oghosenzuhourgroupcom
# 41272               purchasingmanager          rkumarzuhourgroupcom
# 41273                marketingmanager        gtarabayzuhourgroupcom
# 41274  personalassistanttothechairman        ggorospezuhourgroupcom
# 41275                 cateringmanager     skumarzulekhahospitalscom
# 41276                 cateringmanager     skumarzulekhahospitalscom
# 41277                             ceo          mukeshzulkomdubaicom
# 41278            globalprojectmanager       claudiezumarestaurantae
# 41279                     gmzumadubai     florenciazumarestaurantae
# 41280                   executivechef        carloszumarestaurantae
# 41281              exhibitionsmanager       veronicafranceszumexcom
# 41282                   marketinghead                  ninadzummoin
# 41283                     financehead                  arpitzummoin
# 41284                       saleshead                  rahulzummoin
# 41285                   technicalhead               dhavalfrootlein
# 41286                  generalmanager          okyargokpinarzumotjo
# 41287        regionalmarketingmanager            hannahjoaogmailcom
# 41288                    salesmanager  thomaseasozurichfooddubaicom
# 41289                salescoordinator      mikhilzurichfooddubaicom
# 41290                             ceo     mohammadrafiaee20gmailcom
# 41291               operationsmanager      jovezushisharjahgmailcom
# 41292                         manager            mitchzushigmailcom
# 41293                marketingmanager              mpmaslamgmailcom
# 41294                             ceo           zzengroupoutlookcom
#
#                       CompanyName  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16                            NaN
# 17                            NaN
# 18                            NaN
# 19                            NaN
# 20                            NaN
# 21                            NaN
# 22                            NaN
# 23                            NaN
# 24                            NaN
# 25                            NaN
# 26                            NaN
# 27                            NaN
# 28                            NaN
# 29                            NaN
# ...                           ...
# 41265                    zubintea
# 41266  zuckerhandelsuniongmbhcokg
# 41267           zuhorelmuhammadia
# 41268              zuhouralsahara
# 41269                 zuhourgroup
# 41270                 zuhourgroup
# 41271                 zuhourgroup
# 41272                 zuhourgroup
# 41273                 zuhourgroup
# 41274    zuhourgroupofrestaurants
# 41275             zulekhahospital
# 41276             zulekhahospital
# 41277            zulkomtradingfze
# 41278                        zuma
# 41279                        zuma
# 41280              zumarestaurant
# 41281                       zumex
# 41282                  zummoindia
# 41283                  zummoindia
# 41284                  zummoindia
# 41285                  zummoindia
# 41286                  zumotgroup
# 41287               zumtobelgroup
# 41288                 zurichfoods
# 41289   zurichfoodstufftradingllc
# 41290                        zuse
# 41291                       zushi
# 41292                       zushi
# 41293     zytoongeneraltradingllc
# 41294                   zzengroup
#
#                                                   combo1  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 41265                                                NaN
# 41266                                                NaN
# 41267                                                NaN
# 41268                                                NaN
# 41269                                                NaN
# 41270                                                NaN
# 41271                                                NaN
# 41272                                                NaN
# 41273                                                NaN
# 41274                                                NaN
# 41275                                                NaN
# 41276                                                NaN
# 41277                                                NaN
# 41278                                                NaN
# 41279                                                NaN
# 41280                                                NaN
# 41281                                                NaN
# 41282                                                NaN
# 41283                                                NaN
# 41284                                                NaN
# 41285                                                NaN
# 41286                                                NaN
# 41287                                                NaN
# 41288                                                NaN
# 41289                                                NaN
# 41290                                                NaN
# 41291                                                NaN
# 41292                                                NaN
# 41293  muhammedaslammarketingmanagermpmaslamgmailcomz...
# 41294  zeeshanabdulhafeezceozzengroupoutlookcomzzengroup
#
#        combo110DigitCardNumber  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                         NaN
# 25                         NaN
# 26                         NaN
# 27                         NaN
# 28                         NaN
# 29                         NaN
# ...                        ...
# 41265                      NaN
# 41266                      NaN
# 41267                      NaN
# 41268                      NaN
# 41269                      NaN
# 41270                      NaN
# 41271                      NaN
# 41272                      NaN
# 41273                      NaN
# 41274                      NaN
# 41275                      NaN
# 41276                      NaN
# 41277                      NaN
# 41278                      NaN
# 41279                      NaN
# 41280                      NaN
# 41281                      NaN
# 41282                      NaN
# 41283                      NaN
# 41284                      NaN
# 41285                      NaN
# 41286                      NaN
# 41287                      NaN
# 41288                      NaN
# 41289                      NaN
# 41290                      NaN
# 41291                      NaN
# 41292                      NaN
# 41293             7.997002e+09
# 41294             7.197006e+09
#
#                                                   combo2  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 41265                                                NaN
# 41266  christophkindmanagingdirectorzuckerhandelsunio...
# 41267                                                NaN
# 41268                                                NaN
# 41269                                                NaN
# 41270                                                NaN
# 41271                                                NaN
# 41272                                                NaN
# 41273                                                NaN
# 41274                                                NaN
# 41275                                                NaN
# 41276                                                NaN
# 41277                                                NaN
# 41278                                                NaN
# 41279                                                NaN
# 41280                                                NaN
# 41281                                                NaN
# 41282                                                NaN
# 41283                                                NaN
# 41284                                                NaN
# 41285                                                NaN
# 41286                                                NaN
# 41287                                                NaN
# 41288                                                NaN
# 41289                                                NaN
# 41290                                                NaN
# 41291                                                NaN
# 41292                                                NaN
# 41293  muhammedaslammarketingmanagerzytoongeneraltrad...
# 41294                     zeeshanabdulhafeezceozzengroup
#
#        combo210DigitCardNumber      ...      combo710DigitCardNumber  \
# 0                          NaN      ...                          NaN
# 1                          NaN      ...                 7.997004e+09
# 2                          NaN      ...                 7.197007e+09
# 3                          NaN      ...                          NaN
# 4                          NaN      ...                          NaN
# 5                          NaN      ...                          NaN
# 6                          NaN      ...                          NaN
# 7                          NaN      ...                 7.197001e+09
# 8                          NaN      ...                          NaN
# 9                          NaN      ...                          NaN
# 10                         NaN      ...                          NaN
# 11                         NaN      ...                          NaN
# 12                         NaN      ...                          NaN
# 13                         NaN      ...                          NaN
# 14                         NaN      ...                          NaN
# 15                         NaN      ...                          NaN
# 16                         NaN      ...                          NaN
# 17                         NaN      ...                          NaN
# 18                         NaN      ...                          NaN
# 19                         NaN      ...                          NaN
# 20                         NaN      ...                          NaN
# 21                         NaN      ...                          NaN
# 22                         NaN      ...                          NaN
# 23                         NaN      ...                 7.197001e+09
# 24                         NaN      ...                          NaN
# 25                         NaN      ...                          NaN
# 26                         NaN      ...                          NaN
# 27                         NaN      ...                          NaN
# 28                         NaN      ...                          NaN
# 29                         NaN      ...                          NaN
# ...                        ...      ...                          ...
# 41265                      NaN      ...                          NaN
# 41266             7.997003e+09      ...                          NaN
# 41267                      NaN      ...                          NaN
# 41268                      NaN      ...                          NaN
# 41269                      NaN      ...                          NaN
# 41270                      NaN      ...                          NaN
# 41271                      NaN      ...                          NaN
# 41272                      NaN      ...                          NaN
# 41273                      NaN      ...                          NaN
# 41274                      NaN      ...                          NaN
# 41275                      NaN      ...                          NaN
# 41276                      NaN      ...                          NaN
# 41277                      NaN      ...                          NaN
# 41278                      NaN      ...                          NaN
# 41279                      NaN      ...                          NaN
# 41280                      NaN      ...                          NaN
# 41294  zeeshanabdulhafeez             7.197006e+09
#
#                                           combo11 combo1110DigitCardNumber  \
# 0                                             NaN                      NaN
# 1                                             NaN                      NaN
# 2                                             NaN                      NaN
# 3                                             NaN                      NaN
# 4                                             NaN                      NaN
# 5                                             NaN                      NaN
# 6                                             NaN                      NaN
# 7                                             NaN                      NaN
# 8                                             NaN                      NaN
# 9                                             NaN                      NaN
# 10                                            NaN                      NaN
# 11                                            NaN                      NaN
# 12                                            NaN                      NaN
# 13                                            NaN                      NaN
# 14                                            NaN                      NaN
# 15                                            NaN                      NaN
# 16                                            NaN                      NaN
# 17                                            NaN                      NaN
# 18                                            NaN                      NaN
# 19                                            NaN                      NaN
# 20                                            NaN                      NaN
# 21                                            NaN                      NaN
# 22                                            NaN                      NaN
# 23                                            NaN                      NaN
# 24                                            NaN                      NaN
# 25                                            NaN                      NaN
# 26                                            NaN                      NaN
# 27                                            NaN                      NaN
# 28                                            NaN                      NaN
# 29                                            NaN                      NaN
# ...                                           ...                      ...
# 41265                                         NaN                      NaN
# 41266  managingdirectorzuckerhandelsuniongmbhcokg             7.997003e+09
# 41267                                         NaN                      NaN
# 41268                                         NaN                      NaN
# 41269                                         NaN                      NaN
# 41270                                         NaN                      NaN
# 41271                                         NaN                      NaN
# 41272                                         NaN                      NaN
# 41273                                         NaN                      NaN
# 41274                                         NaN                      NaN
# 41275                                         NaN                      NaN
# 41276                                         NaN                      NaN
# 41277                                         NaN                      NaN
# 41278                                         NaN                      NaN
# 41279                                         NaN                      NaN
# 41280                                         NaN                      NaN
# 41281                                         NaN                      NaN
# 41282                                         NaN                      NaN
# 41283                                         NaN                      NaN
# 41284                                         NaN                      NaN
# 41285                                         NaN                      NaN
# 41286                                         NaN                      NaN
# 41287                                         NaN                      NaN
# 41288                                         NaN                      NaN
# 41289                                         NaN                      NaN
# 41290                                         NaN                      NaN
# 41291                                         NaN                      NaN
# 41292                                         NaN                      NaN
# 41293     marketingmanagerzytoongeneraltradingllc             7.997002e+09
# 41294                                ceozzengroup             7.197006e+09
#
#               match
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
# ...             ...
# 41265           NaN
# 41266           NaN
# 41267           NaN
# 41268           NaN
# 41269           NaN
# 41270           NaN
# 41271           NaN
# 41272           NaN
# 41273           NaN
# 41274           NaN
# 41275           NaN
# 41276           NaN
# 41277           NaN
# 41278           NaN
# 41279           NaN
# 41280           NaN
# 41281           NaN
# 41282           NaN
# 41283           NaN
# 41284           NaN
# 41285           NaN
# 41286           NaN
# 41287           NaN
# 41288           NaN
# 41289           NaN
# 41290           NaN
# 41291           NaN
# 41292           NaN
# 41293  7.997002e+09
# 41294  7.197006e+09
#
# [41295 rows x 29 columns]

# %% [markdown]
# Save data as matchedFile.csv

# %%
data = data[['10DigitCardNumber', "FirstName", "Surname", "Position", "Email", "CompanyName", 'match']]
#data = pd.merge(yearTwoData, data, how = 'left', on = '10DigitCardNumber').drop_duplicates()

# %%
#dataFinal = data[['10 Digit Card Number', 'match']]
data.to_csv(r'./dta/matchedFile.csv', index = False)
